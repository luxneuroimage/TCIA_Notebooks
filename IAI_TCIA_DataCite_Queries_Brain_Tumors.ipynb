# %% [markdown]
# You can download and run this notebook locally, or you can run it for free in a cloud environment using Google Colab or Amazon Sagemaker Studio Lab:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kirbyju/TCIA_Notebooks/blob/main/TCIA_DataCite_Queries.ipynb)
#
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github.com/kirbyju/TCIA_Notebooks/blob/main/TCIA_DataCite_Queries.ipynb)

# %% [markdown]
# # Summary
#
# Access to large, high-quality datasets is essential for researchers to understand disease and precision medicine pathways, especially in cancer. However, HIPAA constraints make sharing medical images outside an individual institution complex. [The Cancer Imaging Archive (TCIA)](https://www.cancerimagingarchive.net/) is a public service funded by the National Cancer Institute that addresses this challenge by providing hosting and de-identification services that take major burdens of data sharing off researchers.
#
# **This notebook provides documentation for using the DataCite module of [tcia-utils](https://pypi.org/project/tcia-utils/), which is a package that contains functions to simplify common tasks one might perform when interacting with The Cancer Imaging Archive (TCIA) via Python.**  If you're interested in additional TCIA notebooks and coding examples, check out the tutorials at https://github.com/kirbyju/TCIA_Notebooks.

# %% [markdown]
# # 1. Introduction
# TCIA issues a Digital Object Identifier (DOI) for each of its datasets through [DataCite](https://datacite.org/value.html).  The [DataCite API](https://wiki.cancerimagingarchive.net/x/YwD5BQ) can be used to programmatically access Collection metadata such as their DOI URL, title, publication date, licensing information and abstract.
#
# Please note that **this API was not developed by TCIA.** See https://support.datacite.org/ for any technical questions.  The TCIA Helpdesk may be able to assist if your inquiry is related to the content of the data itself.

# %% [markdown]
# # 2. tcia_utils Overview and Installation
#
# The following cells install and import the DataCite module from [**tcia_utils**](https://pypi.org/project/tcia-utils/).

# %%
# !pip install pip --upgrade -q
# !pip install tcia-utils --upgrade -q
# !pip install pandas --upgrade -q

# %%
import requests
import pandas as pd
from tcia_utils import datacite

# %% [markdown]
# # 3. DataCite Query Examples - Rewritten to get all Datasets mentioning "Tumor and Brain"

# %% [markdown]
# The datacite module contains a single function called **getDOI()**.  This returns metadata for one or more DOIs based on your query parameters.  It returns all TCIA DOIs in **JSON** format if no parameters are specified.

# %%
#datacite.getDoi() # returns a giant JSON of all datasets metadata

# %%
doiDF = datacite.getDoi(format = "df") # same as before but as a DF table

# %%
doiDF
# Out:
#                                       DOI  \
# 0    10.7937/k9/tcia.2018.ow73vlo2/scgvs2
# 1    10.7937/k9/tcia.2018.ow73vlo2/otqf2a
# 2    10.7937/k9/tcia.2018.ow73vlo2/okjdaf
# 3    10.7937/k9/tcia.2018.ow73vlo2/k7oh8k
# 4    10.7937/k9/tcia.2018.ow73vlo2/gjilrf
# ..                                    ...
# 267         10.7937/k9/tcia.2014.v7cvh1jo
# 268         10.7937/k9/tcia.2014.iirmbunx
# 269        10.7937/k9/tcia.2020.85sp-0b40
# 270            10.7937/tcia.2020.zx6hmv94
# 271            10.7937/tcia.2018.h7umfurq
#
#                                      Identifier  \
# 0                              Crowds-Cure-2017
# 1                              Crowds-Cure-2018
# 2                              Crowds-Cure-2017
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 267                                               None
# 268                                               None
# 269                                               None
# 270                                               None
# 271                                               None
#
#                                            Description FundingReferences  \
# 0    RSNA2017CCC-doiJNLP-e8nBWDCC.jnlp\nPlease see ...                []
# 1                     CrowdsCureCancer2018-Results.csv                []
# 2    DICOM-SR representation of crowd measurements\...                []
# 3                        CrowdsCureCancer-dicomsrfiles                []
# 4                                   TCGA Clinical Data                []
# ..                                                 ...               ...
# 267                                               None                []
# 268                                               None                []
# 269  This collection is comprised of imaging segmen...                []
# 270  A Test DOI which should hopefully not post to ...                []
# 271  This dataset contains standardized DICOM repre...                []
#
#                                                    URL  CitationCount  \
# 0    https://wiki.cancerimagingarchive.net/download...              0
# 1    https://wiki.cancerimagingarchive.net/download...              0
# 2       https://wiki.cancerimagingarchive.net/x/ZgQGAg              0
# 3    https://wiki.cancerimagingarchive.net/download...              0
# 4    https://wiki.cancerimagingarchive.net/download...              0
# ..                                                 ...            ...
# 267     https://wiki.cancerimagingarchive.net/x/I4IiAQ              0
# 268     https://wiki.cancerimagingarchive.net/x/JYAiAQ              0
# 269      https://wiki.cancerimagingarchive.net/x/vosvB              0
# 270  http://tcia-path-a1:3001/details?doi=10.7937/T...              0
# 271     https://wiki.cancerimagingarchive.net/x/vwKnAg              0
#
#      ReferenceCount
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 267               0
# 268               0
# 269               0
# 270               0
# 271               0
#
# [272 rows x 15 columns]

# %%
doiDF.Title.str.contains("brain", case = False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 267    False
# 268    False
# 269    False
# 270    False
# 271    False
# Name: Title, Length: 272, dtype: bool

# %%
# search for Tumor                                                    in Title     OR       in Description
dataSetContaningTumorIdxs = doiDF.Title.str.contains("tumor|tumour", case = False) | doiDF.Description.str.contains("tumor|tumour", case = False)
sum(dataSetContaningTumorIdxs)
# Out:
# 113

# %%
# search for Brain                                                in Title     OR       in Description
dataSetContainingBrainIdxs = doiDF.Title.str.contains("brain", case = False) | doiDF.Description.str.contains("brain", case = False)
sum(dataSetContainingBrainIdxs)
# Out:
# 17

# %% [markdown]
# # Get the final dataframe of "Tumor and Brain" datasets

# %%
dataSetTumorAndBrainIdxs = dataSetContaningTumorIdxs & dataSetContainingBrainIdxs
dfTumorAndBrain = doiDF[dataSetTumorAndBrainIdxs]
dfTumorAndBrain
# Out:
#                                       DOI               Identifier  \
# 24             10.7937/tcia.2019.zfv154m9         DI-Cubed-Reports
# 39                 10.7937/tcia.t905-zq20                  GLIS-RT
# 41                      10.7937/xb6d-py67      Brain-TR-GammaKnife
# 43   10.7937/k9/tcia.2018.15quzvnb/4fvupd  Brain-Tumor-Progression
# 49          10.7937/k9/tcia.2015.588ozuzb                REMBRANDT
# 111                10.7937/tcia.bdgf-8v37                UCSF-PDGM
# 112         10.7937/k9/tcia.2017.klxwjj1q           BraTS-TCGA-GBM
# 112  2023-04-27T20:17:14Z   IsReferencedBy: 10.1007/978-3-030-46640-4_14
# 113  2023-04-27T20:11:10Z   IsReferencedBy: 10.1007/978-3-030-46640-4_14
# 119  2023-04-26T22:43:55Z   IsReferencedBy: 10.1007/978-3-319-19578-0_10
# 125  2023-04-26T18:55:05Z  HasPart: 10.7937/k9/tcia.2018.15quzvnb/4fvupd
# 153  2023-01-19T08:55:34Z                                           None
# 182  2022-10-24T15:59:30Z                                           None
# 199  2022-08-14T08:56:52Z           IsReferencedBy: 10.1200/cci.19.00125
# 223  2022-06-21T13:35:15Z            IsReferencedBy: 10.3390/jpm11040310
#
#     Version                                          Rights  \
# 24        1                        TCIA Restricted License
# 39        1                     TCIA Limited Access License
# 41        1                     TCIA Limited Access License
# 43        1                         TCIA Restricted License
# 49        2                         TCIA Restricted License
# 111       4  Creative Commons Attribution 4.0 International
# 112       1       Creative Commons Attribution 3.0 Unported
# 113       1       Creative Commons Attribution 3.0 Unported
# 119       1       Creative Commons Attribution 3.0 Unported
# 125       1                                 TCIA Restricted
# 153       1       Creative Commons Attribution 3.0 Unported
# 182       2  Creative Commons Attribution 4.0 International
# 199       1                                 TCIA Restricted
# 223       2                                 TCIA Restricted
#
#                                              RightsURI  \
# 24   https://wiki.cancerimagingarchive.net/download...
# 39   https://wiki.cancerimagingarchive.net/download...
# 41   https://wiki.cancerimagingarchive.net/download...
# 43   https://wiki.cancerimagingarchive.net/download...
# 49   https://wiki.cancerimagingarchive.net/download...
# 111  https://creativecommons.org/licenses/by/4.0/le...
# 112  https://creativecommons.org/licenses/by/3.0/le...
# 113  https://creativecommons.org/licenses/by/3.0/le...
# 119  https://creativecommons.org/licenses/by/3.0/le...
# 125  https://wiki.cancerimagingarchive.net/download...
# 153  https://creativecommons.org/licenses/by/3.0/le...
# 182  https://creativecommons.org/licenses/by/4.0/le...
# 199  https://wiki.cancerimagingarchive.net/download...
# 223  https://wiki.cancerimagingarchive.net/download...
#
#                                            Description FundingReferences  \
# 24   The Data Integration &amp; Imaging Informatics...                []
# 39   The imaging data consists of 230 cases of glio...                []
# 41   Here we release a brain cancer MRI dataset wit...                []
# 43   Images (DICOM, 3.2GB)\nPlease see DOI:10.7937/...                []
# 49   Finding better therapies for the treatment of ...                []
# 111  The publicly available University of Californi...                []
# 112  This data container describes both computer-ai...                []
# 113  This data container describes both computer-ai...                []
# 119  Ideally a patient’s response to neoadjuvant ch...                []
# 125  This collection includes datasets from 20 subj...                []
# 153  This dataset consists of 140 computed tomograp...                []
# 182  This collection comprises multi-parametric mag...                []
# 199  This data collection consists of MRI/CT scan d...                []
# 223  The objective of the ACRIN 6684 multi-center c...                []
#
#                                                    URL  CitationCount  \
# 24      https://wiki.cancerimagingarchive.net/x/ihklAw              0
# 39      https://wiki.cancerimagingarchive.net/x/pgKtBQ              0
# 41       https://wiki.cancerimagingarchive.net/x/BQSwC              0
# 43   https://wiki.cancerimagingarchive.net/download...              0
# 49   https://wiki.cancerimagingarchive.net/display/...             31
# 111     https://wiki.cancerimagingarchive.net/x/5pAiBw              0
# 112     https://wiki.cancerimagingarchive.net/x/KoZyAQ             33
# 113     https://wiki.cancerimagingarchive.net/x/LIZyAQ             32
# 119     https://wiki.cancerimagingarchive.net/x/dYRXAQ              7
# 125     https://wiki.cancerimagingarchive.net/x/1wEGAg              5
# 153     https://wiki.cancerimagingarchive.net/x/OgWkAw              3
# 182      https://wiki.cancerimagingarchive.net/x/6o4vB              1
# 199     https://wiki.cancerimagingarchive.net/x/jY9XAQ             10
# 223     https://wiki.cancerimagingarchive.net/x/kQIGAg              1
#
#      ReferenceCount
# 24                0
# 39                0
# 41                0
# 43                0
# 49                0
# 111               0
# 112               0
# 113               0
# 119               0
# 125               0
# 153               0
# 182               0
# 199               0
# 223               0

# %% [markdown]
# # Further Examples from original code:

# %% [markdown]
# Using the **format** parameter allows you to return a dataframe or save a CSV spreadsheet for the DOI records.

# %%
datacite.getDoi(format = "df")

# %% [markdown]
# Using the **query** parameter searches most metadata fields DataCite uses. Let's say that we were interested to find all TCIA datasets that mention "lung" in their titles or abstracts and save the output to a CSV file.

# %%
datacite.getDoi(query = "lung", format = "csv")

# %% [markdown]
# The **created** parameter lets you filter by the date the DOI was created.  It expects a 4 digit year.

# %%
datacite.getDoi(created = 2022, format = "df")

# %% [markdown]
# The **license** parameter requires an exact match. Most of our datasets are Creative Commons Attribution licenses. The "nc" variants that prevent commercial use are no longer an option for new datasets in TCIA, but there are a handful that used this before the policy changed.  Datasets using the NCTN Data Archive and TCIA Limited Access licenses both require signing data use agreements, but the others do not require special agreements or creating an account.
#
# **Note:** Some of the license data is not populated for datasets, and in other cases there are minor differences in the names of the license.  We are working to fix this issue.

# %%
datacite.getDoi(license = "NCTN Data Archive License", format = "df")

# %% [markdown]
# # Acknowledgements
# TCIA is funded by the [Cancer Imaging Program (CIP)](https://imaging.cancer.gov/), a part of the United States [National Cancer Institute (NCI)](https://www.cancer.gov/).  It is managed by the [Frederick National Laboratory for Cancer Research (FNLCR)](https://frederick.cancer.gov/) and hosted by the [University of Arkansas for Medical Sciences (UAMS)](https://www.uams.edu/)
#
# This notebook was created by [Justin Kirby](https://www.linkedin.com/in/justinkirby82/). If you leverage this notebook or any TCIA datasets in your work, please be sure to comply with the [TCIA Data Usage Policy](https://wiki.cancerimagingarchive.net/x/c4hF). In particular, make sure to cite the DOI(s) for the specific TCIA datasets you used in addition to the following paper!
#
# ## TCIA Citation
#
# Clark, K., Vendt, B., Smith, K., Freymann, J., Kirby, J., Koppel, P., Moore, S., Phillips, S., Maffitt, D., Pringle, M., Tarbox, L., & Prior, F. (2013). The Cancer Imaging Archive (TCIA): Maintaining and Operating a Public Information Repository. Journal of Digital Imaging, 26(6), 1045–1057. https://doi.org/10.1007/s10278-013-9622-7
